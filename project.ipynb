# %%
import pandas as pd 
from functions.ImportaRelatorios import VendasPorDatas

# %%
df = VendasPorDatas()
df
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# c:\Users\emers\OneDrive - UDESC Universidade do Estado de Santa Catarina\SHOPFARMA\ShopfarmaAnalyser\ShopfarmaAnalyser\project.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/emers/OneDrive%20-%20UDESC%20Universidade%20do%20Estado%20de%20Santa%20Catarina/SHOPFARMA/ShopfarmaAnalyser/ShopfarmaAnalyser/project.ipynb#ch0000001?line=0'>1</a> df = VendasPorDatas()
#       <a href='vscode-notebook-cell:/c%3A/Users/emers/OneDrive%20-%20UDESC%20Universidade%20do%20Estado%20de%20Santa%20Catarina/SHOPFARMA/ShopfarmaAnalyser/ShopfarmaAnalyser/project.ipynb#ch0000001?line=1'>2</a> df
#
# File c:\Users\emers\OneDrive - UDESC Universidade do Estado de Santa Catarina\SHOPFARMA\ShopfarmaAnalyser\ShopfarmaAnalyser\functions\ImportaRelatorios.py:5, in VendasPorDatas()
# ...

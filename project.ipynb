# %%
import pandas as pd 
from functions.ImportaRelatorios import VendasPorDatas

# %%
df = VendasPorDatas()
df
# Out:
#             DINHEIRO  CREDIÁRIO  CONVÊNIO    CARTÃO  TOTAL VENDAS  \
# DATA
# 2022-03-01   5102.69     397.57     70.45  14866.78      20437.49
# 2022-03-02   4779.71     216.77    501.19  14868.47      20366.14
# 2022-03-03   6138.03     225.97    245.28  14883.96      21493.24
# 2022-03-04   6783.86     267.35    223.07  19810.93      27085.21
# 2022-03-05   6011.95     291.69    443.23  16459.16      23206.03
# 2022-03-06   4240.40     128.25    120.18  13034.83      17523.66
# 2022-03-07   4513.68     150.40    308.46  12049.03      17021.57
# 2022-03-08   6259.13     558.61    164.29  15180.41      22162.44
# 2022-03-09   5426.17     417.26    457.88  14576.12      20877.43
# 2022-03-10   4701.59     399.70    477.08  13204.89      18783.26
# 2022-03-11   4992.72     123.87    159.68  16304.09      21580.36
# 2022-03-12   6094.15      13.00     90.92  13323.97      19522.04
# 2022-03-13   3010.58     149.97     86.88   8664.91      11912.34
# ...
